# %% [markdown]
# ## More Important functions

# %%
import numpy as np
import pandas as pd

# %%
# value_counts (series and dataframe) -> give freq count of every unique item

a = pd.Series([1,1,2,5,5,7,8,9,7])
a.value_counts()
# Out:
# 1    2
# 5    2
# 7    2
# 2    1
# 8    1
# 9    1
# Name: count, dtype: int64

# %%
marks = pd.DataFrame([
    [100,80,10],
    [90,70,7],
    [120,100,14],
    [80,70,14],
    [80,70,14]
], columns=['iq','marks','package'])

marks.value_counts()
# marks
# Out:
# iq   marks  package
# 80   70     14         2
# 90   70     7          1
# 100  80     10         1
# 120  100    14         1
# Name: count, dtype: int64

# %%
ipl = pd.read_csv('datasets/ipl-matches.csv')
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
# find which player has won most potm -> in finals and semi finals(qualifiers)
ipl[(ipl['MatchNumber'] == 'Final') | (ipl['MatchNumber'].str.split(' ').apply(lambda x:x[0]) == 'Qualifier')]['Player_of_Match'].value_counts() # long method not good

ipl[~ipl['MatchNumber'].str.isdigit()]['Player_of_Match'].value_counts()# 2nd easy method
# Out:
# Player_of_Match
# F du Plessis         3
# SK Raina             3
# KA Pollard           3
# JJ Bumrah            2
# AB de Villiers       2
# MK Pandey            2
# M Vijay              2
# A Kumble             2
# YK Pathan            2
# SR Watson            2
# HH Pandya            1
# RM Patidar           1
# JC Buttler           1
# RR Pant              1
# KS Williamson        1
# MP Stoinis           1
# TA Boult             1
# SP Narine            1
# RD Gaikwad           1
# VR Iyer              1
# DA Miller            1
# Washington Sundar    1
# NM Coulter-Nile      1
# KV Sharma            1
# BCJ Cutting          1
# KH Pandya            1
# SA Yadav             1
# Rashid Khan          1
# AD Russell           1
# RG Sharma            1
# A Nehra              1
# DA Warner            1
# MC Henriques         1
# Harbhajan Singh      1
# BJ Hodge             1
# UT Yadav             1
# V Sehwag             1
# MS Bisla             1
# MEK Hussey           1
# ...

# %%
#  toss decision plot
apprach_data = (ipl['TossDecision'].value_counts()/950)*100
apprach_data.plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
# how many matches each team has played
(ipl['Team1'].value_counts() + ipl['Team2'].value_counts()).sort_values(ascending=False)
# Out:
# Mumbai Indians                 231
# Royal Challengers Bangalore    226
# Kolkata Knight Riders          223
# Chennai Super Kings            208
# Rajasthan Royals               192
# Kings XI Punjab                190
# Delhi Daredevils               161
# Sunrisers Hyderabad            152
# Deccan Chargers                 75
# Delhi Capitals                  63
# Pune Warriors                   46
# Gujarat Lions                   30
# Punjab Kings                    28
# Gujarat Titans                  16
# Rising Pune Supergiant          16
# Lucknow Super Giants            15
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# Name: count, dtype: int64

# %%
# sort_values (series and dataframe) -> ascending -> na_position -> inplace -> multiple cols
movies = pd.read_csv('datasets/movies.csv')
movies.sort_values('title_x',ascending=False)
# Out:
#                        title_x    imdb_id  \
# 1623                  Zubeidaa  tt0255713
# 939      Zor Lagaa Ke...Haiya!  tt1479857
# 756                   Zokkomon  tt1605790
# 670          Zindagi Tere Naam  tt2164702
# 778   Zindagi Na Milegi Dobara  tt1562872
# ...                        ...        ...
# 1039          1971 (2007 film)  tt0983990
# 723     1920: The Evil Returns  tt2222550
# 287               1920: London  tt5638500
# 1021               1920 (film)  tt1301698
# 1498        16 December (film)  tt0313844
#
#                                             poster_path  \
# 1623  https://upload.wikimedia.org/wikipedia/en/thum...
# 939   https://upload.wikimedia.org/wikipedia/en/thum...
# 756   https://upload.wikimedia.org/wikipedia/en/thum...
# 670   https://upload.wikimedia.org/wikipedia/en/thum...
# 778   https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# 1039  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies.sort_values('poster_path',na_position='last',ascending=False) # na_position put all missing values first if first else last
# Out:
#                               title_x    imdb_id  \
# 292                Phobia (2016 film)  tt5743656
# 390                           Hey Bro  tt4512230
# 1167             Gangster (2006 film)  tt0495032
# 932                        Barah Aana  tt1202517
# 484                        Jal (film)  tt2708550
# ...                               ...        ...
# 1602              Ittefaq (2001 film)  tt0297983
# 1603                Mitti (2001 film)  tt0446159
# 1606  Hadh: Life on the Edge of Death  tt0396044
# 1617              Officer (2001 film)  tt0265452
# 1626                  Sabse Bada Sukh  tt0069204
#
#                                             poster_path  \
# 292   https://upload.wikimedia.org/wikipedia/en/thum...
# 390   https://upload.wikimedia.org/wikipedia/en/thum...
# 1167  https://upload.wikimedia.org/wikipedia/en/thum...
# 932   https://upload.wikimedia.org/wikipedia/en/thum...
# 484   https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
# how to sort multiple values
movies.sort_values(['year_of_release','title_x'],ascending=[True,False])
# Out:
#                                    title_x     imdb_id  \
# 1623                              Zubeidaa   tt0255713
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1622         Yeh Teraa Ghar Yeh Meraa Ghar   tt0298606
# 1620              Yeh Raaste Hain Pyaar Ke   tt0292740
# 1573                   Yaadein (2001 film)   tt0248617
# ...                                    ...         ...
# 37                       Article 15 (film)  tt10324144
# 46                           Arjun Patiala   tt7881524
# 10                                  Amavas   tt8396186
# 26    Albert Pinto Ko Gussa Kyun Aata Hai?   tt4355838
# 21                                22 Yards   tt9496212
#
#                                             poster_path  \
# 1623  https://upload.wikimedia.org/wikipedia/en/thum...
# 1625  https://upload.wikimedia.org/wikipedia/en/thum...
# 1622  https://upload.wikimedia.org/wikipedia/en/thum...
# 1620  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
# ranks(series only)
batsman = pd.read_csv('datasets/batsman_runs_ipl.csv')
batsman
# Out:
#              batter  batsman_run
# 0    A Ashish Reddy          280
# 1          A Badoni          161
# 2        A Chandila            4
# 3          A Chopra           53
# 4       A Choudhary           25
# ..              ...          ...
# 600      Yash Dayal            0
# 601   Yashpal Singh           47
# 602     Younis Khan            3
# 603    Yuvraj Singh         2754
# 604          Z Khan          117
#
# [605 rows x 2 columns]

# %%
batsman['batsman_rank'] = batsman['batsman_run'].rank(ascending=False)
batsman.sort_values('batsman_rank')
# Out:
#              batter  batsman_run  batsman_rank
# 569         V Kohli         6634           1.0
# 462        S Dhawan         6244           2.0
# 130       DA Warner         5883           3.0
# 430       RG Sharma         5881           4.0
# 493        SK Raina         5536           5.0
# ..              ...          ...           ...
# 570  V Pratap Singh            0         594.0
# 63     Abdur Razzak            0         594.0
# 562          U Kaul            0         594.0
# 65       Akash Deep            0         594.0
# 57           AS Roy            0         594.0
#
# [605 rows x 3 columns]

# %%
#  sort_index(series and dataframe)
movies.sort_index(ascending=False)
# Out:
#                                    title_x     imdb_id  \
# 1628                              Humsafar   tt2403201
# 1627                                 Daaka  tt10833860
# 1626                       Sabse Bada Sukh   tt0069204
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1624                 Tera Mera Saath Rahen   tt0301250
# ...                                    ...         ...
# 4                          Evening Shadows   tt6028796
# 3                          Why Cheat India   tt8108208
# 2     The Accidental Prime Minister (film)   tt6986710
# 1                            Battalion 609   tt9472208
# 0                 Uri: The Surgical Strike   tt8291224
#
#                                             poster_path  \
# 1628  https://upload.wikimedia.org/wikipedia/en/thum...
# 1627  https://upload.wikimedia.org/wikipedia/en/thum...
# 1626                                                NaN
# 1625  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
# set_index(dataframe) -> inplace
batsman.set_index('batter',inplace=True)

# %%
batsman
# Out:
#                 batsman_run  batsman_rank
# batter
# A Ashish Reddy          280         166.5
# A Badoni                161         226.0
# A Chandila                4         535.0
# A Chopra                 53         329.0
# A Choudhary              25         402.5
# ...                     ...           ...
# Yash Dayal                0         594.0
# Yashpal Singh            47         343.0
# Younis Khan               3         547.5
# Yuvraj Singh           2754          27.0
# Z Khan                  117         256.0
#
# [605 rows x 2 columns]

# %%
# reset index(series and dataframe) -> drop parameter
print(batsman.reset_index())
# Out:
#              batter  batsman_run  batsman_rank
# 0    A Ashish Reddy          280         166.5
# 1          A Badoni          161         226.0
# 2        A Chandila            4         535.0
# 3          A Chopra           53         329.0
# 4       A Choudhary           25         402.5
# ..              ...          ...           ...
# 600      Yash Dayal            0         594.0
# 601   Yashpal Singh           47         343.0
# 602     Younis Khan            3         547.5
# 603    Yuvraj Singh         2754          27.0
# 604          Z Khan          117         256.0
#
# [605 rows x 3 columns]

# %%
batsman
# Out:
#                 batsman_run  batsman_rank
# batter
# A Ashish Reddy          280         166.5
# A Badoni                161         226.0
# A Chandila                4         535.0
# A Chopra                 53         329.0
# A Choudhary              25         402.5
# ...                     ...           ...
# Yash Dayal                0         594.0
# Yashpal Singh            47         343.0
# Younis Khan               3         547.5
# Yuvraj Singh           2754          27.0
# Z Khan                  117         256.0
#
# [605 rows x 2 columns]

# %%
# how to replace existing index without loosing
batsman.reset_index().set_index('batsman_rank')
# Out:
#                       batter  batsman_run
# batsman_rank
# 166.5         A Ashish Reddy          280
# 226.0               A Badoni          161
# 535.0             A Chandila            4
# 329.0               A Chopra           53
# 402.5            A Choudhary           25
# ...                      ...          ...
# 594.0             Yash Dayal            0
# 343.0          Yashpal Singh           47
# 547.5            Younis Khan            3
# 27.0            Yuvraj Singh         2754
# 256.0                 Z Khan          117
#
# [605 rows x 2 columns]

# %%
# series to dataframe using reset_index
data = {'maths':67,'english':57,'science':89,'hindi':100}
marks_series = pd.Series(data)
type(marks_series.reset_index())
# on using reset_index on series then it will converted into a dataframe
# Out:
# pandas.core.frame.DataFrame

# %%
# rename (dataframe) -> index
movies.set_index('title_x',inplace=True)

# %%
movies.rename(columns={'imdb_id':'imdb','poster_path':'link'},inplace=True)
movies
# Out:
#                                             imdb  \
# title_x
# Uri: The Surgical Strike               tt8291224
# Battalion 609                          tt9472208
# The Accidental Prime Minister (film)   tt6986710
# Why Cheat India                        tt8108208
# Evening Shadows                        tt6028796
# ...                                          ...
# Tera Mera Saath Rahen                  tt0301250
# Yeh Zindagi Ka Safar                   tt0298607
# Sabse Bada Sukh                        tt0069204
# Daaka                                 tt10833860
# Humsafar                               tt2403201
#
#                                                                                    link  \
# title_x
# Uri: The Surgical Strike              https://upload.wikimedia.org/wikipedia/en/thum...
# Battalion 609                                                                       NaN
# The Accidental Prime Minister (film)  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
# rename index
movies.rename(index={'Uri: The Surgical Strike':'Uri','Battalion 609':'Battalion'})
# Out:
#                                             imdb  \
# title_x
# Uri                                    tt8291224
# Battalion                              tt9472208
# The Accidental Prime Minister (film)   tt6986710
# Why Cheat India                        tt8108208
# Evening Shadows                        tt6028796
# ...                                          ...
# Tera Mera Saath Rahen                  tt0301250
# Yeh Zindagi Ka Safar                   tt0298607
# Sabse Bada Sukh                        tt0069204
# Daaka                                 tt10833860
# Humsafar                               tt2403201
#
#                                                                                    link  \
# title_x
# Uri                                   https://upload.wikimedia.org/wikipedia/en/thum...
# Battalion                                                                           NaN
# The Accidental Prime Minister (film)  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
# unique(series)
temp = pd.Series([1,1,2,3,4,5,5,7,9,7,8,5,np.nan,np.nan])
print(temp)
temp.unique().shape
# Out:
# 0     1.0
# 1     1.0
# 2     2.0
# 3     3.0
# 4     4.0
# 5     5.0
# 6     5.0
# 7     7.0
# 8     9.0
# 9     7.0
# 10    8.0
# 11    5.0
# 12    NaN
# 13    NaN
# dtype: float64
# (9,)

# %%
# nunique(series and dataframe) -> not include nan values
temp.nunique()
# Out:
# 8

# %%
# isnull(series and dataframe)
students = [
    {"id": 1, "name": "Ayesha Khan", "age": 20, "gender": "F", "grade": "A", "major": "Computer Science", "email": "ayesha.khan@email.com"},
    {"id": 2, "name": "Rahul Verma", "age": 21, "gender": np.nan, "grade": "B", "major": "Mechanical Engg", "email":pd.NA},
    {"id": np.nan, "name": pd.NA, "age": pd.NA, "gender": pd.NA, "grade": pd.NA, "major": np.nan, "email": np.nan},
    {"id": 4, "name": "Om Patel", "age": 22, "gender": "M", "grade": "C", "major": "IT", "email": "om.patel@email.com"},
    {"id": 5, "name": np.nan, "age": 20, "gender": "F", "grade": "B", "major": "AI & ML", "email": pd.NA}
]
student = pd.DataFrame(students)
del student['email']
student
# Out:
#     id         name   age gender grade             major
# 0  1.0  Ayesha Khan    20      F     A  Computer Science
# 1  2.0  Rahul Verma    21    NaN     B   Mechanical Engg
# 2  NaN         <NA>  <NA>   <NA>  <NA>               NaN
# 3  4.0     Om Patel    22      M     C                IT
# 4  5.0          NaN    20      F     B           AI & ML

# %%
student['name'][student['name'].isnull()]
# Out:
# 2    <NA>
# 4     NaN
# Name: name, dtype: object

# %%
student.isnull()
# Out:
#       id   name    age  gender  grade  major
# 0  False  False  False   False  False  False
# 1  False  False  False    True  False  False
# 2   True   True   True    True   True   True
# 3  False  False  False   False  False  False
# 4  False   True  False   False  False  False

# %%
# notnull(series and dataframe)
student['name'][student['name'].notnull()]
# Out:
# 0    Ayesha Khan
# 1    Rahul Verma
# 3       Om Patel
# Name: name, dtype: object

# %%
student.notnull()
# Out:
#       id   name    age  gender  grade  major
# 0   True   True   True    True   True   True
# 1   True   True   True   False   True   True
# 2  False  False  False   False  False  False
# 3   True   True   True    True   True   True
# 4   True  False   True    True   True   True

# %%
# hasnans(series and dataframe)
student['name'].hasnans
# Out:
# True

# %%
# dropna -> remove all missing values
student['name'].dropna()
# Out:
# 0    Ayesha Khan
# 1    Rahul Verma
# 3       Om Patel
# Name: name, dtype: object

# %%
student.dropna(how='any')# remove row if any row has missing values
# Out:
#     id         name age gender grade             major
# 0  1.0  Ayesha Khan  20      F     A  Computer Science
# 3  4.0     Om Patel  22      M     C                IT

# %%
student.dropna(how='all') # the row contain all missing values elements will remove only
# Out:
#     id         name age gender grade             major
# 0  1.0  Ayesha Khan  20      F     A  Computer Science
# 1  2.0  Rahul Verma  21    NaN     B   Mechanical Engg
# 3  4.0     Om Patel  22      M     C                IT
# 4  5.0          NaN  20      F     B           AI & ML

# %%
student.dropna(subset=['name','gender']) # remove rows on the bases of name
# Out:
#     id         name age gender grade             major
# 0  1.0  Ayesha Khan  20      F     A  Computer Science
# 3  4.0     Om Patel  22      M     C                IT

# %%
# fillna(series and dataframe)
student['name'].fillna('unknown')
# Out:
# 0    Ayesha Khan
# 1    Rahul Verma
# 2        unknown
# 3       Om Patel
# 4        unknown
# Name: name, dtype: object

# %%
student.fillna('0')
# Out:
#     id         name age gender grade             major
# 0  1.0  Ayesha Khan  20      F     A  Computer Science
# 1  2.0  Rahul Verma  21      0     B   Mechanical Engg
# 2    0            0   0      0     0                 0
# 3  4.0     Om Patel  22      M     C                IT
# 4  5.0            0  20      F     B           AI & ML

# %%
student['name'].fillna(method='ffill') # forward fills
student['name'].fillna(method='bfill') # backward fills
# Out:
# C:\Users\bhave\AppData\Local\Temp\ipykernel_23240\4233478087.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   student['name'].fillna(method='ffill') # forward fills
# C:\Users\bhave\AppData\Local\Temp\ipykernel_23240\4233478087.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   student['name'].fillna(method='bfill') # backward fills
# 0    Ayesha Khan
# 1    Rahul Verma
# 2       Om Patel
# 3       Om Patel
# 4            NaN
# Name: name, dtype: object

# %%
marks.duplicated().sum()# no.of duplicated values
marks.drop_duplicates(keep='last')# remove duplicate row and keep help to know which will remove if first -> last occurance remove and last -> vise versa
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 4   80     70       14

# %%
# find the last matched played by virat kohli in dehli
ipl['all_players']= ipl['Team1Players'] + ipl['Team2Players']
def did_kohli_play(players_list):
    return 'V Kohli' in players_list

# %%
ipl['did_kohli_play']=ipl['all_players'].apply(did_kohli_play)
ipl[(ipl['City'] == 'Delhi') & (ipl['did_kohli_play'] == True)].drop_duplicates(subset=['City','did_kohli_play'],keep = 'first')
# Out:
#           ID   City        Date Season MatchNumber           Team1  \
# 208  1178421  Delhi  2019-04-28   2019          46  Delhi Capitals
#
#                            Team2                 Venue      TossWinner  \
# 208  Royal Challengers Bangalore  Arun Jaitley Stadium  Delhi Capitals
#
#     TossDecision  ... WonBy Margin method  Player_of_Match  \
# 208          bat  ...  Runs   16.0    NaN         S Dhawan
#
#                                           Team1Players  \
# 208  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'RR Pant', ...
#
#                                           Team2Players       Umpire1  \
# 208  ['PA Patel', 'V Kohli', 'AB de Villiers', 'S D...  BNJ Oxenford
#
#                    Umpire2                                        all_players  \
# 208  KN Ananthapadmanabhan  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'RR Pant', ...
#
#     did_kohli_play
# 208           True
#
# [1 rows x 22 columns]
